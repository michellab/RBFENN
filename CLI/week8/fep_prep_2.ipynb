# %%
import BioSimSpace as BSS
# Out:
# ==============================================================
# Sending anonymous Sire usage statistics to http://siremol.org.
# For more information, see http://siremol.org/analytics
# To disable, set the environment variable 'SIRE_DONT_PHONEHOME' to 1
# To see the information sent, set the environment variable
# SIRE_VERBOSE_PHONEHOME equal to 1. To silence this message, set
# the environment variable SIRE_SILENT_PHONEHOME to 1.
# ==============================================================

# %%
import openbabel
from openbabel import pybel

# %% [markdown]
# # Ligand series of interest

# %% [markdown]
# ## MAT-POS-dc2604c4-1 (0.036 - MAT-POS-e194df51-1)
# ![image.png](attachment:image.png)
#
# ## EDJ-MED-968bafd9-1 (0.21)
# ![image-2.png](attachment:image-2.png)
#
# ## EDJ-MED-968bafd9-2 (0.77)
# ![image-3.png](attachment:image-3.png)

# %%
#lig1: MAT-POS-e194df51-1 (MAT-POS-dc2604c4-1) - 0.04
#lig3: EDJ-MED-968bafd9-1 (0.21)
#lig4: EDJ-MED-968bafd9-2 (0.77)

# %%
#EDJ-MED-968bafd9-1 (0.21)
lig3_smiles = "COC1(CS(=O)(=O)N2CC(C(=O)Nc3cncc4ccccc34)c3cc(Cl)ccc3C2=O)CC1"

#EDJ-MED-968bafd9-2 (0.77)
lig4_smiles = "COC1(CS(=O)(=O)N2CC(C(=O)Nc3cncc4cc(S(C)(=O)=O)ccc34)c3cc(Cl)ccc3C2=O)CC1"

# %% [markdown]
# # Protein

# %%
protein = BSS.IO.readMolecules("Mpro-P1800_0A_bound-protein.pdb")[0]

# %%
view = BSS.Notebook.View(protein)
view.system()
# Out:
# ThemeManager()
# NGLWidget(gui_style='ngl')
