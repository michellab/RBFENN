# %%
import BioSimSpace as BSS
import pandas as pd
from scipy import stats
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import minmax_scale
import glob
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np
import os
import shutil
from functools import reduce
# Out:
# Process Process-66:
# Process Process-63:
# Process Process-61:
# Process Process-60:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 606, in __init__
#     trim_mcs_chiral_atoms()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 386, in trim_mcs_chiral_atoms
#     map_mcs_mol()   # Regenerate mappings after deletion
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 437, in map_mcs_mol
#     (moli_sub,molj_sub) = best_substruct_match_to_mcs(self.__moli_noh,self.__molj_noh,by_rmsd=self.options.threed)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 133, in best_substruct_match_to_mcs
#     coord_delta = (substructure_centre(moli,mapi)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 102, in substructure_centre
#     sum += mol.GetConformer().GetAtomPosition(i)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 606, in __init__
#     trim_mcs_chiral_atoms()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 323, in trim_mcs_chiral_atoms
#     flag_inverted_atoms_in_mcs()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 286, in flag_inverted_atoms_in_mcs
#     map_mcs_mol()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 437, in map_mcs_mol
#     (moli_sub,molj_sub) = best_substruct_match_to_mcs(self.__moli_noh,self.__molj_noh,by_rmsd=self.options.threed)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 140, in best_substruct_match_to_mcs
#     - coord_delta).LengthSq()
# KeyboardInterrupt
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 601, in __init__
#     trim_mcs_mol(max_deviation=self.options.max3d)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 168, in trim_mcs_mol
#     (mapi,mapj) = best_substruct_match_to_mcs(self.__moli_noh,self.__molj_noh,by_rmsd=True)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 140, in best_substruct_match_to_mcs
#     - coord_delta).LengthSq()
# KeyboardInterrupt
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 606, in __init__
#     trim_mcs_chiral_atoms()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 386, in trim_mcs_chiral_atoms
#     map_mcs_mol()   # Regenerate mappings after deletion
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 437, in map_mcs_mol
#     (moli_sub,molj_sub) = best_substruct_match_to_mcs(self.__moli_noh,self.__molj_noh,by_rmsd=self.options.threed)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 134, in best_substruct_match_to_mcs
#     - substructure_centre(molj,mapj))
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 102, in substructure_centre
#     sum += mol.GetConformer().GetAtomPosition(i)
# KeyboardInterrupt
# Process Process-59:
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 559, in __init__
#     matchChiralTag=False)
# KeyboardInterrupt
# Process Process-64:
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 559, in __init__
#     matchChiralTag=False)
# KeyboardInterrupt
# Process Process-58:
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 559, in __init__
#     matchChiralTag=False)
# KeyboardInterrupt
# Process Process-57:
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 559, in __init__
#     matchChiralTag=False)
# KeyboardInterrupt
# Process Process-65:
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 559, in __init__
#     matchChiralTag=False)
# KeyboardInterrupt
# Process Process-62:
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py", line 571, in compute_mtx
#     MC = mcs.MCS(moli, molj, options=self.options)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/mcs.py", line 559, in __init__
#     matchChiralTag=False)
# KeyboardInterrupt
# [11:52:19] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:19] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:21] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:21] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:22] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:22] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:26] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:26] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:31] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:31] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:48] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:48] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:50] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:50] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:51] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:51] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:52:55] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:52:55] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# [11:53:00] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
#
# RDKit ERROR: [11:53:00] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18
# RDKit ERROR:
# /home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py:770: RuntimeWarning: invalid value encountered in multiply
#   obj = obj * 0.0
# [11:56:43] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:43] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:43] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:43] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:44] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:45] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:45] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:46] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:46] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:46] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:46] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:46] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:46] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:47] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:47] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:47] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:47] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:48] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:48] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:49] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:50] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:50] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:50] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:50] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:52] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:52] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:53] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:53] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:53] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:53] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:53] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:53] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:54] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:55] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:55] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:56] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:56] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:56] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:56] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:57] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:57] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:57] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:57] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:57] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:57] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:58] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:56:58] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:56:59] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# [11:57:00] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
#
# RDKit ERROR: [11:57:00] Can't kekulize mol.  Unkekulized atoms: 11 21 22 23 24
# RDKit ERROR:
# [11:57:00] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
#
# RDKit ERROR: [11:57:00] Can't kekulize mol.  Unkekulized atoms: 11 12 13 14 15 16 27 28 29
# RDKit ERROR:
# /home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/site-packages/BioSimSpace/Align/_lomap/dbmol.py:770: RuntimeWarning: invalid value encountered in multiply
#   obj = obj * 0.0
# [11:57:21] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:21] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:24] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:33] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:50] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:50] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:57:51] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:07] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:07] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:07] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:07] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:10] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:12] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:15] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:15] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [11:58:20] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# ...
# RDKit ERROR:
# [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:41] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:45] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:45] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:45] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:45] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:49] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:10:55] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:04] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:04] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:08] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:11:25] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:12:11] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:12:11] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:12:11] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:12:11] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:12:38] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [12:12:38] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [12:12:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:12:38] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:13:13] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 9 10 12 14 16 18 19
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
#
# RDKit ERROR: [12:15:02] Can't kekulize mol.  Unkekulized atoms: 3 4 6 7 9 11 13 15 16
# RDKit ERROR:
# Exception ignored in: <finalize object at 0x7f3b3c047420; dead>
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/tempfile.py", line 797, in _cleanup
#     _shutil.rmtree(name)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpy4b1s_t3'
# Exception ignored in: <finalize object at 0x7f3b3c047420; dead>
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/tempfile.py", line 797, in _cleanup
#     _shutil.rmtree(name)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpy4b1s_t3'
# Exception ignored in: <finalize object at 0x7f3b3c047420; dead>
# Traceback (most recent call last):
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/tempfile.py", line 797, in _cleanup
#     _shutil.rmtree(name)
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/home/jscheen/miniconda3/envs/biosimspace-dev/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpy4b1s_t3'

# %%
def computeStats(input_df):
    """return statistics input for table to plot."""
    col_labels = ["Random", "ML", "LOMAP"]
    row_labels = ["Pearson r", "MUE /\nkcal$\cdot$mol$^{-1}$", r"Kendall $\tau$"]
    table_vals = []
    for array in [input_df["Random\nSEM [0-1]"], 
                  input_df["ML-Predicted\nSEM [0-1]"],
                  input_df["LOMAP-Score"]
                 ]:
        

        r = round(stats.pearsonr(input_df["True SEM [0-1]"], array)[0], 2)
        mue = round(mean_absolute_error(input_df["True SEM [0-1]"], array), 2)
        tau = round(stats.kendalltau(input_df["True SEM [0-1]"], array)[0], 2)
        table_vals.append([r, mue, tau])
        
    # need to transpose table values to fit the row/col layout.
    table_vals = np.array(table_vals).T.tolist()
    return col_labels, row_labels, table_vals
    
#col_labels, row_labels, table_vals = computeStats(sems_combined_df)

# %%
def generateLinksFiles(preds_path):
    """Given a csv file with SEM predictions, write out links files for LOMAP.
    Because SEMs are the inverse of LOMAP (i.e. LOMAP-score 0.0 is poor, but SEM 0.0 is good), 
    we need to invert the predicted SEM values. Additionally, compress them to fall in the range 0-1 
    as is the case with LOMAP-scores."""
    
    preds_df = pd.read_csv(preds_path)
    pert_names = preds_df["pert_name"].values
    
    # for these, take inverse and scale to 0-1.
    pred_sems = minmax_scale(1 / preds_df["pred_sem_mean"].values, feature_range=(0,1))
    
    random_sems = preds_df["random_sem"].values
    return pert_names, pred_sems, random_sems
        
def writeLinksFile(pert_names, values, filename):
    with open(filename, "w") as writefile:
        writer = csv.writer(writefile, delimiter =" ")
        for pert_name, value in zip(pert_names, values):
            writer.writerow([pert_name, value])

# %%
def runLOMAP(tgt, links_file):
    path_to_ligands = f"/home/jscheen/projects/FEPSPACE/fep_ref_ligands/{tgt}"
    ligand_files = glob.glob(f"{path_to_ligands}/*.mol2")

    ligands = []
    ligand_names = []

    for filepath in ligand_files:
        # append the molecule object to a list.
        ligands.append(BSS.IO.readMolecules(filepath)[0])

        # append the molecule name to another list so that we can use the name of each molecule in our workflow.
        ligand_names.append(filepath.split("/")[-1].replace(".mol2",""))
    
    # now run LOMAP. Even if we have a links_file, we need to run a 'vanilla' LOMAP first to get the work dir.      
    tranformations, lomap_scores = BSS.Align.generateNetwork(ligands, plot_network=False, names=ligand_names,
                                                            work_dir="tmp/lomap_workdir") 
    if links_file:
        links_file = f"tmp/lomap_ml_links_file_{tgt}.csv"
        # bit of a workaround, but we have to find the mol2 file names that LOMAP uses internally.  
        # write out a second linksfile that doesn't have the tilde to denote the perturbations. Also
        # use glob in the pre-generated LOMAP work folder to find what we should call our ligands (i.e.
        # refer to the internal LOMAP file name).
        links_file_contents = pd.read_csv(links_file, sep=" ", header=None)
        lomap_internal_files = glob.glob("tmp/lomap_workdir/inputs/*.mol2")
        internal_links_file_path = links_file.replace(".csv", "_internal.csv")

        with open(internal_links_file_path, "w") as writefile:
            writer = csv.writer(writefile, delimiter =" ")
            lig1, lig2 = None, None
            for pert_name, value in zip(links_file_contents[0].values, links_file_contents[1].values):
                # find the internal path.
                for lig in lomap_internal_files:
                    if pert_name.split("~")[0] in lig:
                        lig1 = lig.split("/")[-1]
                    elif pert_name.split("~")[1] in lig:
                        lig2 = lig.split("/")[-1]
                if lig1 and lig2:
                    writer.writerow([lig1, lig2, value])



        # now run LOMAP with the pre-specified edge scorings.
        tranformations, lomap_scores = BSS.Align.generateNetwork(ligands, plot_network=True, names=ligand_names,
                                                                links_file=internal_links_file_path)    
    else:   
        tranformations, lomap_scores = BSS.Align.generateNetwork(ligands, plot_network=True, names=ligand_names) 
    
    pert_network_dict = {}
    transformations_named = [(ligand_names[transf[0]], ligand_names[transf[1]]) for transf in tranformations]
    for transf, score in zip(transformations_named, lomap_scores):
        transf_tilde = "~".join(transf)
        pert_network_dict[transf_tilde] = score

    return tranformations, lomap_scores, pert_network_dict

# %%
def compareNetworks(tgt_to_do, input_type):
    # clear all links files from ./tmp.
    [os.remove(linkspath) for linkspath in glob.glob("tmp/lomap*.csv")]
    shutil.rmtree("tmp/lomap_workdir", ignore_errors=True)
    for sem_preds_file in glob.glob("output/series_predictions/*"):
        tgt = sem_preds_file.split("/")[-1].replace(".csv","")
        
        if tgt_to_do in tgt:
            # tmp to be able to do quick network generation.
            print(tgt)

            if not ".csv" in sem_preds_file:
                pert_names, pred_sems, random_sems = generateLinksFiles(sem_preds_file+".csv")
            else:
                pert_names, pred_sems, random_sems = generateLinksFiles(sem_preds_file)
            writeLinksFile(pert_names, pred_sems, f"tmp/lomap_ml_links_file_{tgt}.csv")

            ligand_files = glob.glob(f"/home/jscheen/projects/FEPSPACE/fep_ref_ligands/{tgt}/*.mol2")
            ligands = []
            ligand_names = []
            if input_type == "naive":
                print("Running LOMAP naively..")
                tranformations, scores, pert_network_dict = runLOMAP(tgt, links_file=False)
            elif input_type == "ml":
                print("Running ML-LOMAP..")
                tranformations, scores, pert_network_dict = runLOMAP(tgt, links_file=True)
            return tranformations, scores, pert_network_dict

# %%
def computeNetworkOverlap(tranformations, tranformations_ml):
    overlap = 0
    unique = 0
    for edge_lomap in tranformations:

        inv_edge = (edge_lomap[1], edge_lomap[0])
        if edge_lomap in tranformations_ml:
            overlap += 1
        elif inv_edge in tranformations_ml:
            overlap += 1
        else:
            unique += 1

    total = overlap + unique
    perc_overlap = int(overlap/total*100)
    print(f"{perc_overlap}% overlap between naive LOMAP and ML-LOMAP networks (n={len(tranformations)}; n={len(tranformations_ml)}, resp.)")

# %%
tranformations, scores, pert_network_dict = compareNetworks("pde2", "naive")
# Out:
# pde2
# Running LOMAP naively..

# %%
tranformations_ml, scores_ml, pert_network_dict_ml = compareNetworks("pde2", "ml")
# Out:
# pde2
# Running ML-LOMAP..

# %%
computeNetworkOverlap(tranformations, tranformations_ml)
# Out:
# 6% overlap between naive LOMAP and ML-LOMAP networks (n=29; n=29, resp.)
